# %%
from pathlib import Path
import shutil
import numpy as np

# %%
RUN_DIR  = Path("/project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs")
MOLD_DIR = Path("/project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/mold")
ANG_DIR  = Path("/project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/angles/runs")
NUM_SUB = 4
NWINDOWS_DIST = 12
NWINDOWS_ANG  = 18

# %% [markdown]
# # Preparations

# %%
def write_plumed(id, dist, ang, k_d, k_a, circ_id, plumed_f):
    plumed_cnt = [ "WHOLEMOLECULES ENTITY0=99-151 ENTITY1=1-98\n",
                   "# DEFINITIONS\n",
                   "MOLcom: COM ATOMS=99-151\n",
                   "PCCcom: COM ATOMS=1-98\n",
                   "# COLVARS\n",
                   "dcom: DISTANCE ATOMS=MOLcom,PCCcom\n",
                   "ang: ANGLE ATOMS=5,8,101,129\n",
                   "v1: DISTANCE ATOMS=5,8 SCALED_COMPONENTS NOPBC\n",
                   "v2: DISTANCE ATOMS=101,129 SCALED_COMPONENTS NOPBC\n",
                   "vr: DISTANCE ATOMS=PCCcom,2 SCALED_COMPONENTS NOPBC\n",
                   "crossx: CUSTOM ...\n",
                   "\tARG=v1.b,v1.c,v2.b,v2.c\n",
                   "\tVAR=y1,z1,y2,z2\n",
                   "\tFUNC=y1*z2-y2*z1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "crossy: CUSTOM ...\n",
                   "\tARG=v1.a,v1.c,v2.a,v2.c\n",
                   "\tVAR=x1,z1,x2,z2\n",
                   "\tFUNC=x2*z1-x1*z2\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "crossz: CUSTOM ...\n",
                   "\tARG=v1.a,v1.b,v2.a,v2.b\n",
                   "\tVAR=x1,y1,x2,y2\n",
                   "\tFUNC=x1*y2-x2*y1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "crosss: CUSTOM ...\n",
                   "\tARG=crossx,crossy,crossz\n",
                   "\tVAR=x,y,z\n",
                   "\tFUNC=sqrt(x*x+y*y+z*z)\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refx: CUSTOM ...\n",
                   "\tARG=v1.b,v1.c,vr.b,vr.c\n",
                   "\tVAR=y1,z1,y2,z2\n",
                   "\tFUNC=y1*z2-y2*z1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refy: CUSTOM ...\n",
                   "\tARG=v1.a,v1.c,vr.a,vr.c\n",
                   "\tVAR=x1,z1,x2,z2\n",
                   "\tFUNC=x2*z1-x1*z2\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refz: CUSTOM ...\n",
                   "\tARG=v1.a,v1.b,vr.a,vr.b\n",
                   "\tVAR=x1,y1,x2,y2\n",
                   "\tFUNC=x1*y2-x2*y1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refs: CUSTOM ...\n",
                   "\tARG=refx,refy,refz\n",
                   "\tVAR=x,y,z\n",
                   "\tFUNC=sqrt(x*x+y*y+z*z)\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "dc: CUSTOM ...\n",
                   "\tARG=crossx,crossy,crossz,refx,refy,refz,crosss,refs\n",
                   "\tVAR=x1,y1,z1,x2,y2,z2,A,B\n",
                   "\tFUNC=(x1*x2+y1*y2+z1*z2)/A/B\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "# BIAS\n",
                   f"udb: RESTRAINT ARG=dcom KAPPA={k_d} AT={dist}\n",
                   f"uab: RESTRAINT ARG=ang KAPPA={k_a} AT={ang}\n",
                   f"ucb: RESTRAINT ARG=dc KAPPA=100.0 AT={circ_id}\n",
                   "\n",
                   f"PRINT ARG=dcom,ang,dc,udb.bias,uab.bias,ucb.bias STRIDE=100 FILE=us_{id}.dat\n",
                    ]
    with open(plumed_f, 'w') as f:
        f.writelines(plumed_cnt)

def write_sub(f_name, ang_dir, ang_id):
    with open(f_name, 'r' ) as f:
        f_cnt = f.readlines()
    line = f_cnt[-3]
    line = line.replace("$ANG_DIR", str(ang_dir/f"{ang_id}"))
    f_cnt[-3] = line
    with open(f_name, 'w' ) as f:
        f.writelines(f_cnt)
    return None

# %%
DISTS = np.linspace(0, 2.5, NWINDOWS_DIST)
ANGS = np.linspace(0, np.pi, NWINDOWS_ANG)

for i, ang in enumerate(ANGS):
    for j, dist in enumerate(DISTS):
        ang_dir = RUN_DIR/f"{i}"
        if not ang_dir.exists():
            ang_dir.mkdir()

        sim_dir = RUN_DIR/f"{i}"/f"{j}"
        if sim_dir.exists():
            is_empty = not any(sim_dir.iterdir())
            if not is_empty:
                #raise RuntimeError(f"Directory {i}/{j} already exists and is not empty.")
                print(f"Directory {sim_dir} exists. Skipping...")
                continue
        else:
            sim_dir.mkdir()

        for file in MOLD_DIR.iterdir():
            shutil.copy(file, sim_dir/file.parts[-1])
        plumed_f = sim_dir/"plumed_us.dat"
        write_plumed(f"{i}_{j}", dist, ang, 250.00, 250.00, 0.5, plumed_f)
        sub_f = sim_dir/f"sub_mdrun_plumed.sh"
        write_sub(sub_f, ANG_DIR, i)
# Out:
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/1/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/2/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/3/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/4/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/5/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/6/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/7/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/8/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/9/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/10/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/11/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/12/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/13/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/14/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/15/11 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/0 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/1 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/2 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/3 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/4 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/5 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/6 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/7 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/8 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/9 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/10 exists. Skipping...
# Directory /project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs/16/11 exists. Skipping...

# %%
ANGS = ANGS[1:-1]
ANGS = ANGS[::-1]

for i, ang in enumerate(ANGS):
    for j, dist in enumerate(DISTS):
        ang_id = 18 + i
        ang_dir = RUN_DIR/f"{ang_id}"
        if not ang_dir.exists():
            ang_dir.mkdir()

        sim_dir = RUN_DIR/f"{ang_id}"/f"{j}"
        if sim_dir.exists():
            is_empty = not any(sim_dir.iterdir())
            if not is_empty:
                raise RuntimeError(f"Directory {ang_id}/{j} already exists and is not empty.")
        else:
            sim_dir.mkdir()

        for file in MOLD_DIR.iterdir():
            shutil.copy(file, sim_dir/file.parts[-1])
        plumed_f = sim_dir/"plumed_us.dat"
        write_plumed(f"{ang_id}_{j}", dist, ang, 1000.00, 1000.00, -1, plumed_f)
        sub_f = sim_dir/f"sub_mdrun_plumed.sh"
        write_sub(sub_f, ANG_DIR, ang_id)

# %% [markdown]
# # Submission

# %% [markdown]
# Just a little context manager for changing directories

# %%
import os
import contextlib

@contextlib.contextmanager
def working_directory(path):
    """Changes working directory and returns to previous on exit."""
    prev_cwd = Path.cwd()
    os.chdir(path)
    try:
        yield
    finally:
        os.chdir(prev_cwd)

# %%
import subprocess
import multiprocessing

def call_func(ids):
   i, j = ids
   with working_directory(RUN_DIR/str(i)/str(j)):
      print(f"{i}_{j}: ", end="")
      subprocess.call("sbatch -J GHGGF_us --wait sub_mdrun_plumed.sh", shell=True)
   return None

ids = []
for i in range(NWINDOWS_ANG*2-2):
   for j in range(NWINDOWS_DIST):
      if i in [0, 17]:
         ids.append((i, j))

with multiprocessing.Pool(NUM_SUB) as pool:
   pool.map(call_func, ids)
# Out:
# 0_0: 0_2: 0_6: 0_4:
# Submitted batch job 31078439
# Submitted batch job 31078440
# Submitted batch job 31078441
# Submitted batch job 31078442
# 0_1: 0_5: 0_7: 0_3: Submitted batch job 31078462
# Submitted batch job 31078463
# Submitted batch job 31078464
# Submitted batch job 31078465
# 0_8: 0_10: 17_0: 17_2: Submitted batch job 31078595
# Submitted batch job 31078596
# Submitted batch job 31078597
# Submitted batch job 31078598
# 17_1: 0_9: 0_11: 17_3: Submitted batch job 31078617
# Submitted batch job 31078618
# Submitted batch job 31078619
# Submitted batch job 31078620
# 17_4: 17_6: 17_8: Submitted batch job 31078702
# Submitted batch job 31078703
# Submitted batch job 31078704
# 17_10: Submitted batch job 31078732
# 17_11: 17_5: 17_7: 17_9: Submitted batch job 31078753
# Submitted batch job 31078754
# Submitted batch job 31078755
# Submitted batch job 31078756

# %%
import os
import asyncio
import telegram

async def notif(message):
    bot = telegram.Bot("")
    async with bot:
        await bot.send_message(chat_id=149407364, text=message)


await notif(f"{os.getcwd()} is done.")
