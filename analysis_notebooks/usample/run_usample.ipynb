# %%
from pathlib import Path
import shutil
import numpy as np

# %%
RUN_DIR =    Path("/project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/5ns/runs")
MOLD_DIR =   Path("/project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/5ns/mold")
INIT_DIR =   Path("/project2/andrewferguson/armin/FE_DATA/GHGGF_FEN/complex/usample_2d/prep/distances/runs")
NUM_SUB = 4
NWINDOWS_DIST = 12
NWINDOWS_ANG  = 18
INIT_FLAG = False

# %% [markdown]
# # Preparations

# %%
def write_plumed(id, dist, ang, k_d, k_a, plumed_f):
    plumed_cnt = [ "WHOLEMOLECULES ENTITY0=99-151 ENTITY1=1-98\n",
                   "# DEFINITIONS\n",
                   "MOLcom: COM ATOMS=99-151\n",
                   "PCCcom: COM ATOMS=1-98\n",
                   "# COLVARS\n",
                   "dcom: DISTANCE ATOMS=MOLcom,PCCcom\n",
                   "ang: ANGLE ATOMS=5,8,101,129\n",
                   "v1: DISTANCE ATOMS=5,8 SCALED_COMPONENTS NOPBC\n",
                   "v2: DISTANCE ATOMS=101,129 SCALED_COMPONENTS NOPBC\n",
                   "vr: DISTANCE ATOMS=PCCcom,2 SCALED_COMPONENTS NOPBC\n",
                   "crossx: CUSTOM ...\n",
                   "\tARG=v1.b,v1.c,v2.b,v2.c\n",
                   "\tVAR=y1,z1,y2,z2\n",
                   "\tFUNC=y1*z2-y2*z1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "crossy: CUSTOM ...\n",
                   "\tARG=v1.a,v1.c,v2.a,v2.c\n",
                   "\tVAR=x1,z1,x2,z2\n",
                   "\tFUNC=x2*z1-x1*z2\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "crossz: CUSTOM ...\n",
                   "\tARG=v1.a,v1.b,v2.a,v2.b\n",
                   "\tVAR=x1,y1,x2,y2\n",
                   "\tFUNC=x1*y2-x2*y1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "crosss: CUSTOM ...\n",
                   "\tARG=crossx,crossy,crossz\n",
                   "\tVAR=x,y,z\n",
                   "\tFUNC=sqrt(x*x+y*y+z*z)\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refx: CUSTOM ...\n",
                   "\tARG=v1.b,v1.c,vr.b,vr.c\n",
                   "\tVAR=y1,z1,y2,z2\n",
                   "\tFUNC=y1*z2-y2*z1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refy: CUSTOM ...\n",
                   "\tARG=v1.a,v1.c,vr.a,vr.c\n",
                   "\tVAR=x1,z1,x2,z2\n",
                   "\tFUNC=x2*z1-x1*z2\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refz: CUSTOM ...\n",
                   "\tARG=v1.a,v1.b,vr.a,vr.b\n",
                   "\tVAR=x1,y1,x2,y2\n",
                   "\tFUNC=x1*y2-x2*y1\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "refs: CUSTOM ...\n",
                   "\tARG=refx,refy,refz\n",
                   "\tVAR=x,y,z\n",
                   "\tFUNC=sqrt(x*x+y*y+z*z)\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "dc: CUSTOM ...\n",
                   "\tARG=crossx,crossy,crossz,refx,refy,refz,crosss,refs\n",
                   "\tVAR=x1,y1,z1,x2,y2,z2,A,B\n",
                   "\tFUNC=(x1*x2+y1*y2+z1*z2)/A/B\n",
                   "\tPERIODIC=NO\n",
                   "...\n",
                   "# BIAS\n",
                   f"udb: RESTRAINT ARG=dcom KAPPA={k_d} AT={dist}\n",
                   f"uab: RESTRAINT ARG=ang KAPPA={k_a} AT={ang}\n",
                   "\n",
                   f"PRINT ARG=dcom,ang,dc,udb.bias,uab.bias STRIDE=100 FILE=us_{id}.dat\n",
                    ]
    with open(plumed_f, 'w') as f:
        f.writelines(plumed_cnt)

def write_sub(f_name, init_dir, ang_id, dist_id):
    with open(f_name, 'r' ) as f:
        f_cnt = f.readlines()
    line = f_cnt[-3]
    line = line.replace("$ANG_DIR", str(init_dir/f"{ang_id}"/f"{dist_id}"))
    f_cnt[-3] = line
    with open(f_name, 'w' ) as f:
        f.writelines(f_cnt)
    return None

# %%
DISTS = np.linspace(0, 2.5, NWINDOWS_DIST)
ANGS1 = np.linspace(0, np.pi, NWINDOWS_ANG)
ANGS2 = ANGS1[1:-1]
ANGS2 = ANGS2[::-1]
ANGS = np.concatenate((ANGS1, ANGS2), axis=0)

# %%
if INIT_FLAG:
    for i, ang in enumerate(ANGS):
        for j, dist in enumerate(DISTS):
            sim_dir = RUN_DIR/f"{i}_{j}"
            if sim_dir.exists():
                is_empty = not any(sim_dir.iterdir())
                if not is_empty:
                    raise RuntimeError(f"Directory {i}/{j} already exists and is not empty.")
            else:
                sim_dir.mkdir()
    
            for file in MOLD_DIR.iterdir():
                shutil.copy(file, sim_dir/file.parts[-1])
            
            plumed_f = sim_dir/"plumed_us.dat"
            write_plumed(f"{i}_{j}", dist, ang, 250.00, 250.00, plumed_f)
    
            sub_f = sim_dir/f"sub_mdrun_plumed.sh"
            write_sub(sub_f, INIT_DIR, i, j)

# %% [markdown]
# # Submission

# %% [markdown]
# Just a little context manager for changing directories

# %%
import os
import contextlib

@contextlib.contextmanager
def working_directory(path):
    """Changes working directory and returns to previous on exit."""
    prev_cwd = Path.cwd()
    os.chdir(path)
    try:
        yield
    finally:
        os.chdir(prev_cwd)

# %%
import subprocess
import multiprocessing

def call_func(ids):
   i, j = ids
   with working_directory(RUN_DIR/f"{i}_{j}"):
      gro_dir = Path.cwd()/"md.gro"
      if gro_dir.exists():
         print(f"{i}_{j}: Skipping")
      else:
         print(f"{i}_{j}: ", end="")
         subprocess.call("sbatch -J GHGGF_us --wait sub_mdrun_plumed.sh", shell=True)
   return None

ids = []
for i in range(len(ANGS)):
   for j in range(len(DISTS)):
      ids.append((i, j))


with multiprocessing.Pool(NUM_SUB) as pool:
   pool.map(call_func, ids)
# Out:
# 4_4: Skipping
# 0_0: Skipping
# 0_1: Skipping
# 6_6: Skipping2_2: Skipping
#
# 6_7: Skipping
# 6_8: 4_5: Skipping
# 0_2: Skipping
# 2_3: Skipping
# 0_3: Skipping
# 0_4: Skipping
# 0_5: Skipping
# 0_6: Skipping
# 2_4: Skipping
# 0_7: Skipping
# 2_5: Skipping
# 4_6: Skipping
# 2_6: Skipping
# 2_7: Skipping
# 2_8: Skipping0_8: Skipping
#
# 2_9: Skipping0_9: Skipping
#
# 2_10: Skipping0_10: Skipping
#
# 2_11: Skipping
# 0_11: Skipping
# 3_0: Skipping1_0: Skipping
#
# 3_1: Skipping
# 4_7: Skipping3_2: Skipping
#
# 3_3: 4_8: Skipping
# 22_1: Submitted batch job 31176187
# 18_0: Submitted batch job 31176269
# 20_0: Submitted batch job 31176274
# 24_4: Submitted batch job 31176381
# 22_2: Submitted batch job 31176409
# 18_1: Submitted batch job 31176588
# 20_1: Submitted batch job 31176593
# 24_5: Submitted batch job 31176775
# 22_3: Submitted batch job 31176879
# 18_2: Submitted batch job 31177027
# 20_2: Submitted batch job 31177029
# 24_6: Submitted batch job 31177171
# 22_4: Submitted batch job 31177308
# 18_3: Submitted batch job 31177536
# 20_3: Submitted batch job 31177537
# 24_7: Submitted batch job 31177594
# 22_5: Submitted batch job 31178037
# 18_4: Submitted batch job 31178048
# 20_4: Submitted batch job 31178049
# 24_8: Submitted batch job 31178056
# 22_6: Submitted batch job 31178504
# 18_5: Submitted batch job 31178520
# 20_5: Submitted batch job 31178529
# 24_9: Submitted batch job 31178535
# 22_7: Submitted batch job 31178674
# 18_6: Submitted batch job 31178691
# 20_6: Submitted batch job 31178695
# 24_10: Submitted batch job 31178711
# 22_8: Submitted batch job 31178862
# 18_7: Submitted batch job 31178871
# 20_7: Submitted batch job 31178872
# 24_11: Submitted batch job 31179042
# 22_9: Submitted batch job 31179886
# 20_8: 18_8: Submitted batch job 31179987
# Submitted batch job 31179988
# 25_0: Submitted batch job 31180126
# 22_10: Submitted batch job 31180967
# 18_9: 20_9: Submitted batch job 31181059
# Submitted batch job 31181060
# 25_1: Submitted batch job 31181158
# 22_11: Submitted batch job 31181852
# 20_10: Submitted batch job 31181854
# 18_10: Submitted batch job 31181875
# 25_2: Submitted batch job 31182029
# 18_11: Submitted batch job 31182526
# 20_11: Submitted batch job 31182768
# 23_0: Submitted batch job 31182791
# 25_3: Submitted batch job 31182916
# 19_0: Submitted batch job 31183399
# 21_0: Submitted batch job 31183569
# 23_1: Submitted batch job 31183684
# 25_4: Submitted batch job 31183753
# 19_1: Submitted batch job 31183895
# 21_1: Submitted batch job 31184366
# 23_2: Submitted batch job 31184513
# 25_5: Submitted batch job 31184568
# 19_2: Submitted batch job 31184789
# 25_6: Submitted batch job 31185254
# 21_2: Submitted batch job 31185258
# 23_3: Submitted batch job 31185372
# 19_3: Submitted batch job 31185636
# 25_7: Submitted batch job 31186059
# 21_3: Submitted batch job 31186131
# 23_4: Submitted batch job 31186207
# 19_4: Submitted batch job 31186490
# 25_8: Submitted batch job 31186927
# 21_4: Submitted batch job 31186973
# 23_5: Submitted batch job 31187072
# 19_5: Submitted batch job 31187318
# 25_9: Submitted batch job 31187751
# 21_5: Submitted batch job 31187798
# 23_6: Submitted batch job 31187975
# 26_0: Submitted batch job 31188201
# 25_10: Submitted batch job 31188606
# 21_6: Submitted batch job 31188721
# 23_7: Submitted batch job 31188933
# 26_1: Submitted batch job 31189104
# 25_11: Submitted batch job 31189650
# 21_7: Submitted batch job 31189859
# 23_8: Submitted batch job 31190313
# 26_2: Submitted batch job 31190440
# 28_2: Submitted batch job 31191004
# 30_4: Submitted batch job 31191220
# 23_9: Submitted batch job 31191576
# 26_3: Submitted batch job 31191589
# 28_3: Submitted batch job 31192144
# 30_5: Submitted batch job 31192197
# 32_6: Submitted batch job 31192723
# 26_4: Submitted batch job 31192742
# 28_4: Submitted batch job 31193663
# 30_6: Submitted batch job 31193853
# 26_5: Submitted batch job 31194239
# 32_7: Submitted batch job 31194262
# 28_5: Submitted batch job 31194775
# 30_7: Submitted batch job 31194954
# 26_6: Submitted batch job 31195265
# 32_8: Submitted batch job 31195337
# 28_6: Submitted batch job 31195786
# 30_8: Submitted batch job 31195975
# 26_7: Submitted batch job 31196399
# 32_9: Submitted batch job 31196430
# 28_7: Submitted batch job 31196750
# 30_9: Submitted batch job 31197099
# 26_8: Submitted batch job 31197844
# 32_10: Submitted batch job 31197890
# 28_8: Submitted batch job 31198210
# 30_10: Submitted batch job 31198551
# 26_9: Submitted batch job 31198755
# 32_11: Submitted batch job 31198758
# 28_9: Submitted batch job 31199099
# 30_11: Submitted batch job 31199444
# 26_10: Submitted batch job 31199556
# 33_0: Submitted batch job 31199584
# 28_10: Submitted batch job 31199988
# 31_0: Submitted batch job 31200325
# 33_1: Submitted batch job 31200635
# 26_11: Submitted batch job 31200637
# 28_11: Submitted batch job 31202217
# 31_1: Submitted batch job 31202333
# 27_0: Submitted batch job 31202432
# 33_2: Submitted batch job 31202433
# 29_0: Submitted batch job 31203661
# 31_2: Submitted batch job 31203718
# 33_3: Submitted batch job 31203831
# 27_1: Submitted batch job 31203841
# 31_3: Submitted batch job 31204260
# 29_1: Submitted batch job 31204736
# 33_4: Submitted batch job 31204856
# 27_2: Submitted batch job 31204857
# 31_4: Submitted batch job 31205311
# 29_2: Submitted batch job 31205887
# 33_5: Submitted batch job 31205891
# 27_3: Submitted batch job 31205896
# 31_5: Submitted batch job 31206177
# 29_3: Submitted batch job 31206827
# 27_4: Submitted batch job 31206834
# 33_6: Submitted batch job 31206870
# 31_6: Submitted batch job 31207159
# 27_5: Submitted batch job 31207782
# 29_4: Submitted batch job 31207811
# 33_7: Submitted batch job 31207841
# 31_7: Submitted batch job 31208615
# 27_6: Submitted batch job 31209142
# 29_5: Submitted batch job 31209146
# 33_8: Submitted batch job 31209208
# 31_8: Submitted batch job 31209558
# 29_6: Submitted batch job 31210249
# 27_7: Submitted batch job 31210293
# 33_9: Submitted batch job 31210693
# 31_9: Submitted batch job 31211246
# 27_8: Submitted batch job 31212972
# 29_7: Submitted batch job 31212977
# 33_10: Submitted batch job 31213665
# 31_10: Submitted batch job 31213990
# 27_9: Submitted batch job 31215708
# 29_8: Submitted batch job 31215752
# 33_11: Submitted batch job 31216407
# 31_11: Submitted batch job 31216665
# 27_10: Submitted batch job 31218543
# 29_9: Submitted batch job 31218694
# 32_0: Submitted batch job 31220138
# 27_11: Submitted batch job 31222662
# 29_10: Submitted batch job 31223918
# 32_1: Submitted batch job 31223942
# 28_0: Submitted batch job 31228799
# 32_2: Submitted batch job 31229455
# 29_11: Submitted batch job 31229700
# 28_1: Submitted batch job 31234410
# 32_3: Submitted batch job 31234679
# 30_0: Submitted batch job 31234893
# 32_4: Submitted batch job 31238609
# 30_1: Submitted batch job 31239242
# 32_5: Submitted batch job 31243628
# 30_2: Submitted batch job 31244304
# 30_3: Submitted batch job 31249613

# %%
import os
import asyncio
import telegram

async def notif(message):
    bot = telegram.Bot("5848656908:AAHqbFxp3yrPyZNOSgeUUP59aD8_5pB3lLc")
    async with bot:
        await bot.send_message(chat_id=149407364, text=message)


await notif(f"{os.getcwd()} is done.")
